# %%
import os

f_path = "D:/bdd100k/images/train/"
file_list = os.listdir(f_path)
s_cmd = "python main.py "

ego_path = "D:/bdd100k/Egos/"
ego_list = os.listdir(ego_path)

for i in file_list:

    temp = i + '.txt'
    
    if temp in ego_list:
        continue
    
    r_cmd = s_cmd + f_path + i +'/images/' 
    print(r_cmd)
    os.system(r_cmd)
# Out:
# python main.py D:/bdd100k/images/train/02b7b9ee-74fb981c/images/
# python main.py D:/bdd100k/images/train/02b7b9ee-7d7a2e00/images/
# python main.py D:/bdd100k/images/train/02b7b9ee-a2aba88b/images/
# python main.py D:/bdd100k/images/train/02b7b9ee-a76d996e/images/
# python main.py D:/bdd100k/images/train/02bb67ae-0a494249/images/
# python main.py D:/bdd100k/images/train/02bb67ae-7627384f/images/
# python main.py D:/bdd100k/images/train/02bb67ae-8c3d61f8/images/
# python main.py D:/bdd100k/images/train/02bd959c-f20a2437/images/
# python main.py D:/bdd100k/images/train/02be9032-17072dbc/images/
# python main.py D:/bdd100k/images/train/02c01e62-c53e91a0/images/
# python main.py D:/bdd100k/images/train/02c0b2f1-6a191bd8/images/
# python main.py D:/bdd100k/images/train/02c10fe6-dd186de7/images/
# python main.py D:/bdd100k/images/train/02c14339-b5be3a6c/images/
# python main.py D:/bdd100k/images/train/02c26e9d-02585e70/images/
# ...
